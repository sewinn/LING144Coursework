# %%
#!/usr/bin/env python
# -*- coding: UTF-8 -*-

punct = ',.;:'

dictionary = {} #initializing an empty dictionary
string = '''When I was little, I thought a python was a snake.
            Now I know it is really a monster in disguise.
            But I will prevail over this hideous beast.'''


def checkPunct(w):
    """
    Strips word w of punctuation.
    
    Args:
        w: a word
    
    Returns:
        w: word bare of punctuation
        
    Raises:
        Nothing.
    """
    if w[-1] in punct:
        w = w[:-1]
        w = w
        return w
    else:
        w = w
        return w
    
string = string.strip()
string1 = string.split()
text = []

for w in string1:
    token = checkPunct(w)
    if token != 'I':
        token = token.lower()
    text.append(token)
text = sorted(set(text))        
print text

defn = []
definitions = ["First person, singular, subject personal pronoun.", 
               "One; any indefinite example of; used to denote a singular item of a group.",
               "Any animal other than a human; usually only applied to land vertebrates, especially large or dangerous four-footed ones.",
               "Without, apart from, except.", "Attire (e.g. clothing, makeup) used to hide one's identity or assume another.",
               "Frightful; shocking; extremely ugly.", "Contained by; surrounded by; part of; during",
               "third-person singular simple present indicative form of be", 
               "The third-person singular personal pronoun used to refer to an inanimate object, to an inanimate thing with no or unknown sex or gender.",
               "To be certain or sure about; to be acquainted or familiar with", "Small in size; insignificant, trivial",
               "A terrifying and dangerous, wild or fictional creature; a bizarre or whimsical creature.",
               "Present; current", "Finished, ended, or concluded.", 
               "To be superior in strength, dominance, influence or frequency; to have or gain the advantage over others; to have the upper hand; to outnumber others",
               "A type of large constricting snake.", "Actually; in fact; in reality.",
               "A legless reptile of the sub-order Serpentes with a long, thin body and a fork-shaped tongue.",
               "The (thing) here (used in indicating something or someone nearby).",
               "Form created in the mind, rather than the forms perceived through the five senses; an instance of thinking.",
               "First-person/ third-person singular simple past tense indicative of be.",
               "Used to introduce questions about time.", "To wish, desire."]
pos = ["pron.", "det.", "n.", "prep.", "n.", "adj.", "prep.", "v.", "pron.", "v.", "adj.", "n.", "adj.", "adj.", "v.", "n.",
       "adv.", "n.", "det.", "n.", "v.", "adv.", "v."]
phon = ["aɪ", "eɪ", "biːst", "bʌt", "dɪsˈɡaɪz", "ˈhɪd.iː.ʌs", "ɪn", "ɪz", "ɪt", "noʊ", "ˈlɪɾl̩", "ˈmɑnstɚ", "naʊ̯", "ˈoʊ.vɚ", "pɹi'veɪl",
        "ˈpaɪθɑːn", "ˈɹiəli", "sneɪk", "ðɪs", "θɔːt", "wʌz", "wɛn", "wɪl"]

phonDict = {}
    
print phonDict

entries = {}
'''entries.append(defn)'''

'''
entries = defn + \npos + \nphon
'''

'''
for keys in text:
    for values in entries:
        dictionary = dict(zip(keys, values))
        '''

'''dictionary = dict(zip(definitions,zip(pos, phon)))
print dictionary'''

dictionary["python"] = {"def": "A type of large constricting snake.",
                        "pos": "n",
                        "phon": "ˈpaɪθɑːn"}


#dictionary = dict(zip('list of words', 'list of entries')
# Out:
# ['I', 'a', 'beast', 'but', 'disguise', 'hideous', 'in', 'is', 'it', 'know', 'little', 'monster', 'now', 'over', 'prevail', 'python', 'really', 'snake', 'this', 'thought', 'was', 'when', 'will']
# ['phon']
